# %%
import trimesh
import numpy as np

# %%
path = "/home/computergraphics/Documents/jszymkowiak/mono-vid-dynamic-gs/code/static-background-model/sample_input/bear/gs-input_E2FGVI/scene.glb"

# %%
scene = trimesh.load(path)
geom = scene.geometry["geometry_0"]
vertices = geom.vertices

# %%
geom.visual.vertex_colors
# Out:
# TrackedArray([[ 47,  42,  39, 255],
#               [ 63,  58,  55, 255],
#               [ 70,  65,  61, 255],
#               ...,
#               [169, 156, 149, 255],
#               [155, 142, 135, 255],
#               [161, 148, 141, 255]], dtype=uint8)

# %%
np.array(vertices)
# Out:
# array([[-0.18148963, -0.1122654 ,  0.4515619 ],
#        [-0.18063895, -0.11227459,  0.45130554],
#        [-0.182412  , -0.1138728 ,  0.45739251],
#        ...,
#        [ 0.04774532,  0.03306562,  0.11973543],
#        [ 0.04816817,  0.03320674,  0.12106893],
#        [ 0.04891666,  0.033521  ,  0.12359605]])

# %%
scene.geometry
# Out:
# OrderedDict([('geometry_0',
#               <trimesh.PointCloud(vertices.shape=(14734940, 3))>),
#              ('geometry_1',
#               <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>),
#              ('geometry_2',
#               <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(48, 3))>),
#              ('geometry_3',
#               <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>),
#              ('geometry_4',
#               <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(48, 3))>),
#              ('geometry_5',
#               <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>),
#              ('geometry_6',
#               <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(48, 3))>),
#              ('geometry_7',
#               <trimesh.Trimesh(vertices.shape=(4, 3), faces.shape=(4, 3))>),
#              ('geometry_8',
#               <trimesh.Trimesh(vertices.shape=(14, 3), faces.shape=(48, 3))>),
# ...
